# %%
from IPython.display import display, Image
display(Image(filename='quiz2-1.png'))
display(Image(filename='quiz2-2.png'))
display(Image(filename='quiz2-3.png'))
display(Image(filename='quiz2-4.png'))
display(Image(filename='quiz2-5.png'))
display(Image(filename='quiz2-6.png'))
display(Image(filename='quiz2-7.png'))
